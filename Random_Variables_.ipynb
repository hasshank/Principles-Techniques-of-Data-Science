# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
dist_df = pd.DataFrame({"x":[3,4,6,8],
  "P(X=x)":[0.1,0.2,0.4,0.3]})
dist_df
# Out:
#    x  P(X=x)
# 0  3     0.1
# 1  4     0.2
# 2  6     0.4
# 3  8     0.3

# %%
fig= px.bar(dist_df, x="x",y="P(X=x)", title="Distribution of X")
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b1ab86fc-dd19-4f2b-89e1-2c9a1a07fd8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1ab86fc-dd19-4f2b-89e1-2c9a1a07fd8e")) {                    Plotly.newPlot(                        "b1ab86fc-dd19-4f2b-89e1-2c9a1a07fd8e",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003eP(X=x)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[3,4,6,8],"xaxis":"x","y":[0.1,0.2,0.4,0.3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type" ...

# %%
N=80000
samples=np.random.choice(
    dist_df["x"],
    size=N,
    p=dist_df["P(X=x)"])

sim_df = pd.DataFrame({"X(s)":samples})
sim_df
# Out:
#        X(s)
# 0         3
# 1         8
# 2         8
# 3         8
# 4         6
# ...     ...
# 79995     6
# 79996     6
# 79997     6
# 79998     6
# 79999     6
#
# [80000 rows x 1 columns]

# %%
fig = px.histogram(sim_df, x=("X(s)"), title="Empirical distribution of X",
                   histnorm="probability")
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a67ef36a-af4e-4e68-887f-f295930f9dd0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a67ef36a-af4e-4e68-887f-f295930f9dd0")) {                    Plotly.newPlot(                        "a67ef36a-af4e-4e68-887f-f295930f9dd0",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"probability","hovertemplate":"X(s)=%{x}\u003cbr\u003eprobability=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[3,8,8,8,6,3,6,8,6,6,3,6,4,6,4,3,8,3,8,4,4,8,6,6,8,8,6,4,4,6,3,6,6,3,6,8,4,8,6,6,8,8,3,8,6,6,8,4,8,8,8,6,8,4,4,8,8,8,6,6,4,8,8,6,8,3,6,8,4,8,8,4,3,8,4,4,8,6,8,6,4,8,8,4,8,4,6,8,6,3,4,8,3,4,8,8,6,8,6,6,8,6,6,3,6,8,6,3,6,4,6,6,6,6,6,3,8,6,4,8,8,8,6,6,4,4,6,4,8,4,6,8,8,8,6,8,8,4,8,6,3,3,3,8,8,6,6,8,3,6,6,4,8,4,8,6,6,6,8,4,6,4,6,8,6,3,8,6,6,8,4,6,8,4,4,8,6,6,6,8,8,6,8,6,4,4,6,4,4,8,8,4,6,8,3,6,6,6,6,3,8,6,4,6,8,6,8,8,6,8,3,8,4,6,6,3,3,6,6,8,6,3,8,8,6,8,8,6,6,6,6,8,6,6,8,6,8,6,6,8,3,4,8,8,3,6,8,8,4,8,8,8,6,6,3,4,4,6,6,8,3,6,6,6,6,8,8,3,6,8,8,4,8,6,8,6,4,4,6,6,6,8,3,8,8,8,8,3,6,6,6,6,4,8,6,6,6,6,6,6,4,6,6,4,4,8,8,6,8,6,6,4,8,6,6,8,4,4,3,8,8,6,8,6,8,4,8,8,6,8,8,8,8,6,6,8,8,4,6,8,6,4,4,3,6,8,6,6,8,4,4,6,4,4,6,6,4,6,6,6,8,8,3,4,6,6,6,6,8,6,4,6,6,4,4,8,4,4,6,8,8,4,8,6,8,8,6,4,6,4,6,8,8,6,4,6,6,8,6,6,4,8,6,4,3,6,4,8,6,6,8,6,6,4,8,8,6,4,4,6,6,6,6,4,8,8,6,6,6,4,3,6,6,3,6,6,6,
8,8,8,8,6,8,3,8,8,6,6,8,4,6,8,6,4,6,8,8,6,6,6,8,4,4,6,6,4,4,6,8,8,4,8,8,8,8,6,4,8,6,4,8,6,6,4,6,6,3,3,6,8,8,8,6,8,6,3,4,6,6,8,6,6,3,6,8,6,8,4,4,8,6,8,8,4,6,6,8,8,6,8,8,6,6,6,3,6,6,6,3,6,8,8,4,8,6,8,3,4,3,4,3,4,8,8,8,8,4,8,4,4,8,8,8,6,4,6,6,4,6,4,8,6,4,4,8,8,6,3,8,4,6,8,3,4,4,6,6,6,8,3,3,8,8,8,8,3,8,8,6,6,6,8,3,8,6,6,6,6,8,6,8,6,6,8,3,4,4,8,8,8,8,6,4,6,8,6,6,3,6,8,8,3,6,6,4,6,3,6,6,6,6,8,8,6,4,6,6,4,8,8,4,3,6,8,6,6,8,6,6,6,3,4,4,4,8,3,6,4,6,6,6,8,6,6,3,8,4,8,8,8,6,8,6,8,4,6,6,6,6,6,4,3,4,8,4,6,8,8,8,8,6,8,6,6,6,6,6,3,6,3,6,8,6,8,3,8,6,6,8,8,6,8,8,6,3,8,4,8,6,3,6,8,6,8,4,4,8,3,8,8,6,6,4,6,8,6,6,8,6,4,8,6,3,8,6,6,4,4,6,6,8,6,6,6,6,6,3,4,8,8,8,4,4,6,6,6,4,8,8,6,6,4,8,4,8,6,8,8,8,8,8,6,6,6,4,8,6,6,8 ...

# %%
print("Simulated E[X]:", sim_df['X(s)'].mean())
print("Simulated Var[X]:", sim_df['X(s)'].var())
# Out:
# Simulated E[X]: 5.9069
# Simulated Var[X]: 2.8930185527336603

# %%
E_x = dist_df["x"] @ dist_df["P(X=x)"]
print("E[X]:", E_x)
# Out:
# E[X]: 5.9

# %%
Var_x = dist_df["x"]**2 @ dist_df["P(X=x)"] - E_x**2
print("Var[X]:", Var_x)
# Out:
# Var[X]: 2.8900000000000006

# %%
roll_df = pd.DataFrame({"x": [1,2,3,4,5,6],
                        "P(X=x)": np.ones(6)/6})
roll_df
# Out:
#    x    P(X=x)
# 0  1  0.166667
# 1  2  0.166667
# 2  3  0.166667
# 3  4  0.166667
# 4  5  0.166667
# 5  6  0.166667

# %%
fig = px.bar(roll_df, x="x", y="P(X=x)", title="Distribution of X")
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9691ab54-cc9c-43cf-99b8-d4b14d167aca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9691ab54-cc9c-43cf-99b8-d4b14d167aca")) {                    Plotly.newPlot(                        "9691ab54-cc9c-43cf-99b8-d4b14d167aca",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003eP(X=x)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[1,2,3,4,5,6],"xaxis":"x","y":[0.16666666666666666,0.16666666666666666,0.16666666666666666,0.16666666666666666,0.16666666666666666,0.16666666666666666],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"sca ...

# %%
N = 80000

sim_rolls_df = pd.DataFrame({
    "X_1": np.random.choice(roll_df["x"], size=N, p=roll_df["P(X=x)"]),
    "X_2": np.random.choice(roll_df["x"], size=N, p=roll_df["P(X=x)"])
})

sim_rolls_df
# Out:
#        X_1  X_2
# 0        2    2
# 1        6    4
# 2        1    5
# 3        6    5
# 4        6    3
# ...    ...  ...
# 79995    3    3
# 79996    1    5
# 79997    1    3
# 79998    4    5
# 79999    3    2
#
# [80000 rows x 2 columns]

# %%
sim_rolls_df['Y'] = 2 * sim_rolls_df['X_1']
sim_rolls_df['Z'] = sim_rolls_df['X_1'] + sim_rolls_df['X_2']
sim_rolls_df
# Out:
#        X_1  X_2   Y   Z
# 0        2    2   4   4
# 1        6    4  12  10
# 2        1    5   2   6
# 3        6    5  12  11
# 4        6    3  12   9
# ...    ...  ...  ..  ..
# 79995    3    3   6   6
# 79996    1    5   2   6
# 79997    1    3   2   4
# 79998    4    5   8   9
# 79999    3    2   6   5
#
# [80000 rows x 4 columns]

# %%
px.histogram(sim_rolls_df[["Y", "Z"]].melt(), x="value", color="variable",
             barmode="overlay", histnorm="probability",
             title="Empirical Distributions")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fce66b33-06f4-4bd9-837c-1415937bdab4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fce66b33-06f4-4bd9-837c-1415937bdab4")) {                    Plotly.newPlot(                        "fce66b33-06f4-4bd9-837c-1415937bdab4",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"probability","hovertemplate":"variable=Y\u003cbr\u003evalue=%{x}\u003cbr\u003eprobability=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Y","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"Y","offsetgroup":"Y","orientation":"v","showlegend":true,"x":[4,12,2,12,12,6,12,12,10,12,6,10,6,6,4,2,12,12,12,8,12,4,8,6,4,2,12,2,10,2,12,8,6,12,2,10,6,10,8,12,8,2,4,2,8,10,2,6,6,10,10,12,2,4,8,4,8,4,6,2,8,8,4,2,2,4,2,10,12,2,6,4,2,2,2,2,12,4,10,6,8,12,4,12,6,10,2,2,10,8,12,6,2,4,6,2,12,2,12,10,4,2,10,8,10,8,8,12,2,12,10,10,2,6,10,2,2,2,8,4,6,12,2,8,8,4,8,2,12,4,2,12,6,8,2,12,8,2,6,2,6,12,6,2,10,2,2,8,2,4,10,12,12,2,4,6,4,2,10,12,6,10,6,4,2,10,10,12,2,12,6,6,4,4,8,2,6,6,10,4,10,6,6,8,12,6,2,2,4,4,10,12,4,10,10,6,2,12,2,12,8,10,8,12,4,12,4,2,12,6,2,8,4,12,6,6,10,8,6,8,8,12,2,10,2,12,8,2,8,8,4,10,12,4,10,12,4,12,12,10,2,4,12,12,10,6,8,6,12,2,2,4,12,10,10,2,6,2,4,12,2,8,2,6,6,12,4,12,10,6,4,8,2,6,8,6,8,12,2,12,8,6,8,10,6,2,8,8,6,10,10,2,2,2,10,2,12,6,6,10,4,8,6,8,6,10,8,4,10,10,10,10,12,12,6,8,8,12,12,8,4,6,10,8,8,8,2,2,6,12,6,2,6,12,12,12,6,8,8,8,4,12,12,12,10,10,8,4,2,2,2,8,10,8,12,6,8,2,6,10,12,4,8,2,2,6,10,8,6,6,12,10,6,12,8,10,8,8,8,10,12,10,10,12,8,6,4,12,2,4,6,8,12,6,8,2,8,4,10,4,2,2,12,2,6,10,10,10,4,8,8,8,2,12,4,6,12,6,2,12,10,12,4,12,2,12,8,12,6,12,12,12,6,4,8,2,10,6,2,12,4,8,2,12,12,2,10,4,8,6,12,8,12,4,10,12,12,8,2,6,2,12,2,2,6,12,8,2,10,8,6,10,8,4,2,2,10,12,6,4,6,2,4,2,2,8,4,2,10,12,10,4,12,8,4,8,2,4,8,12,8,6,12,10,8,4,12,10,12,12,2,4,6,10,6,4,12,10,2,6,10,6,12,2,6,12,2,10,10,10,10,10,12,4,8,8,6,10,8,2,6,10,10
    sim_rolls_df[["Y", "Z"]].mean().rename("Mean"),
    sim_rolls_df[["Y", "Z"]].var().rename("Var"),
    np.sqrt(sim_rolls_df[["Y", "Z"]].var()).rename("SD")
])
# Out:
#               Y         Z
# Mean   7.011775  7.011838
# Var   11.719508  5.843895
# SD     3.423377  2.417415

# %%
p = 0.5
coin_df = pd.DataFrame({"x": [1,0],
                        "P(X=x)": [p,1-p]})
coin_df
# Out:
#    x  P(X=x)
# 0  1     0.5
# 1  0     0.5

# %%
N = 10000

np.random.rand(N,2) < p
# Out:
# array([[ True,  True],
#        [False,  True],
#        [ True,  True],
#        ...,
#        [ True,  True],
#        [ True,  True],
#        [False, False]])

# %%
sim_flips = pd.DataFrame(
    {"Choice A": np.sum((np.random.rand(N,2) < p) * 10, axis = 1)})
sim_flips
# Out:
#       Choice A
# 0           10
# 1           20
# 2            0
# 3           10
# 4            0
# ...        ...
# 9995        10
# 9996        10
# 9997        10
# 9998        10
# 9999        10
#
# [10000 rows x 1 columns]

# %%
sim_flips["Choice B"] = np.sum((np.random.rand(N,20) < p), axis = 1)
sim_flips
# Out:
#       Choice A  Choice B
# 0           10         9
# 1           20        12
# 2            0        11
# 3           10        12
# 4            0         8
# ...        ...       ...
# 9995        10        12
# 9996        10        15
# 9997        10         8
# 9998        10        10
# 9999        10         7
#
# [10000 rows x 2 columns]

# %%
sim_flips["Choice C"] = 20 * (np.random.rand(N,1) < p)
sim_flips
# Out:
#       Choice A  Choice B  Choice C
# 0           10         9         0
# 1           20        12         0
# 2            0        11        20
# 3           10        12        20
# 4            0         8         0
# ...        ...       ...       ...
# 9995        10        12         0
# 9996        10        15        20
# 9997        10         8        20
# 9998        10        10         0
# 9999        10         7         0
#
# [10000 rows x 3 columns]

# %%
px.histogram(sim_flips.melt(), x="value", facet_row="variable",
             barmode="overlay", histnorm="probability",
             title="Empirical Distributions",
             width=600, height=600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1dc0ea18-ffab-4f7b-b4c6-357ca18685b4" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1dc0ea18-ffab-4f7b-b4c6-357ca18685b4")) {                    Plotly.newPlot(                        "1dc0ea18-ffab-4f7b-b4c6-357ca18685b4",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"probability","hovertemplate":"variable=Choice A\u003cbr\u003evalue=%{x}\u003cbr\u003eprobability=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[10,20,0,10,0,10,10,20,10,10,0,20,20,10,20,10,0,10,10,10,0,0,20,20,10,10,0,0,10,10,20,10,0,10,10,0,20,10,0,0,0,10,0,10,20,10,10,10,10,20,10,10,0,10,10,10,20,10,10,10,0,0,10,10,10,10,20,10,10,20,0,20,0,20,10,0,10,10,10,0,10,10,20,20,0,10,10,20,0,0,0,10,0,20,10,10,20,10,0,10,10,20,20,10,0,10,10,20,0,10,10,10,0,10,20,0,10,20,10,10,10,10,0,10,20,0,10,20,20,0,20,10,10,10,0,10,20,10,0,20,10,0,10,10,0,20,10,20,20,10,0,10,20,0,10,20,10,0,0,10,0,10,20,10,10,20,0,0,0,20,20,0,10,10,0,10,20,10,0,10,0,0,20,20,0,10,10,10,20,0,20,10,20,20,10,10,0,20,10,10,0,0,0,0,10,20,10,20,20,0,10,10,10,0,10,0,10,0,0,20,10,20,10,0,10,
,10,10,0,10,10,20,20,10,20,10,10,10,0,10,10,10,20,10,10,20,10,0,0,10,20,20,10,10,10,0,0,0,10,20,20,0,0,20,10,20,20,10,10,0,0,0,10,20,0,10,0,10,10,20,20,0,10,20,10,10,10,20,10,0,10,10,10,0,20,10,10,10,10,0,0,0,20,20,10,0,0,0,0,20,0,10,10,10,20,10,0,20,10,10,0,20,0,10,10,0,0,10,10,20,20,10,10,0,10,10,0,20,10,10,20,10,0,0,20,0, ...

# %%
pd.DataFrame([
    sim_flips.mean().rename("Mean"),
    sim_flips.var().rename("Var"),
    np.sqrt(sim_flips.var()).rename("SD")
])
# Out:
#        Choice A  Choice B    Choice C
# Mean  10.067000  9.985700   10.002000
# Var   49.850496  4.996195  100.009997
# SD     7.060488  2.235217   10.000500

# %%
dist_df
# Out:
#    x  P(X=x)
# 0  3     0.1
# 1  4     0.2
# 2  6     0.4
# 3  8     0.3

# %%
N = 100000
all_samples = np.random.choice(dist_df["x"], N, p=dist_df["P(X=x)"])
sim_pop_df = pd.DataFrame({"X(s)":all_samples})
sim_pop_df
# Out:
#        X(s)
# 0         8
# 1         8
# 2         6
# 3         8
# 4         8
# ...     ...
# 99995     6
# 99996     3
# 99997     3
# 99998     6
# 99999     3
#
# [100000 rows x 1 columns]

# %%
n = 100
sample_df = (
    sim_pop_df.sample(n, replace=True)
    .reset_index(drop=True)
    .rename(columns={"X(s)": "X"})
)
sample_df
# Out:
#     X
# 0   4
# 1   8
# 2   6
# 3   8
# 4   8
# .. ..
# 95  4
# 96  4
# 97  8
# 98  4
# 99  4
#
# [100 rows x 1 columns]

# %%
px.histogram(sample_df, x="X", histnorm="probability", title="Sample (n=100)")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="03793d2d-db4d-4dac-a821-8f1ce8ccfa9a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03793d2d-db4d-4dac-a821-8f1ce8ccfa9a")) {                    Plotly.newPlot(                        "03793d2d-db4d-4dac-a821-8f1ce8ccfa9a",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"probability","hovertemplate":"X=%{x}\u003cbr\u003eprobability=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[4,8,6,8,8,4,8,6,6,4,8,4,6,4,6,8,6,6,6,4,8,4,6,8,3,8,6,8,6,6,6,6,8,8,3,4,6,6,4,6,8,6,4,6,6,6,6,6,6,8,4,8,3,6,6,6,8,8,4,4,8,8,8,4,4,4,8,8,6,6,6,3,6,8,8,3,6,3,4,3,4,6,8,8,6,8,4,8,8,6,4,8,8,8,8,4,4,8,4,4],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6", ...

# %%
px.histogram(sim_df, x="X(s)", histnorm="probability", title="Population of X")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="faf56b07-a2aa-4000-87aa-d71adc6f164c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("faf56b07-a2aa-4000-87aa-d71adc6f164c")) {                    Plotly.newPlot(                        "faf56b07-a2aa-4000-87aa-d71adc6f164c",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"probability","hovertemplate":"X(s)=%{x}\u003cbr\u003eprobability=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[3,8,8,8,6,3,6,8,6,6,3,6,4,6,4,3,8,3,8,4,4,8,6,6,8,8,6,4,4,6,3,6,6,3,6,8,4,8,6,6,8,8,3,8,6,6,8,4,8,8,8,6,8,4,4,8,8,8,6,6,4,8,8,6,8,3,6,8,4,8,8,4,3,8,4,4,8,6,8,6,4,8,8,4,8,4,6,8,6,3,4,8,3,4,8,8,6,8,6,6,8,
8,4,8,4,6,4,4,8,6,3,6,4,8,4,8,8,4,3,6,6,8,6,6,6,6,8,6,8,8,4,4,3,3,8,3,8,8,8,4,8,4,6,6,6,8,8,6,8,8,6,6,8,8,6,6,6,4,3,4,6,4,6,3,6,8,8,8,8,6,6,8,6,6,4,8,6,4,8,4,8,3,4,8,6,4,6,3,8,6,6,8,4,6,4,8,6,4,6,6,8,6,4,6,4,6,4,6,8,8,8,6,3,6,8,8,8,8,4,8,6,3,6,6,8,6,8,8,8,6,8,6,8,8,6,4,6,4,4,4,8,6,8,3,6,6,8,6,6,8,3,6,6,8,4,6,6,4,4,6,4,3,6,6,8,6,6,6,6,6,3,6,6,6,8,6,8,4,3,3,8,6,8,6,8,8,6,8,3,3,6,6,3,6,6,6,4,8,4,8,6,8,6,8,6,8,4,8,8,4,3,6,8,4,8,4,4,6,8,6,8,6,6,6,6,6,8,8,8,4,8,8,4,3,6,8,3,6,4,6,3,8,8,8,6,6,6,8,6,8,6,6,4,3,4,8,6,8,3,6,8,3,4,3,6,4,4,6,8,6,6,4,6,6,4,4,6,6,6,6,4,4,6,8,8,6,8,6,3,6,6,8,8,6,4,8,6,8,6,3,6,6,6,6,8,6,8,3,8,4,6,3,6,6,6,8,6,8,6,6,3,4,4,8,6,6,6,8,8,6,4,8,6,6,6,8,6,8,8,8,8,6,8,3,8,8,6,6,8,4,6,8,6,4,6,8,8,6,6,6,8,4,4,6,6,4,4,6,8,8,4,8,8,8,8,6,4,8,6,4,8,6,6,4,6,6,3,3,6,8,8,8,6,8,6,3,4,6,6,8,6,6,3,6,8,6,8,4,4,8,6,8,8,4,6,6,8,8,6,8,8,6,6,6,3,6,6,6,3,6,8,8,4,8,6,8,3,4,3,4,3,4,8,8,8,8,4,8,4,4,8,8,8,6,4,6,6,4,6,4,8,6,4,4,8,8,6,3,8,4,6,8,3,4,4,6,6,6,8,3,3,8,8,8,8,3,8,8,6,6,6,8,3,8,6,6,6,6,8,6,8,6,6,8,3,4,4,8,8,8,8,6,4,6,8,6,6,3,6,8,8,3,6,6,4,6,3,6,6,6,6,8,8,6,4,6,6,4,8,8,4,3,6,8,6,6,8,6,6,6,3,4,4,4,8,3,6,4,6,6,6,8,6,6,3,8,4,8,8,8,6,8,6,8,4,6,6,6,6,6,4,3,4,8,4,6,8,8,8,8,6,8,6,6,6,6,6,3,6,3,6,8,6,8,3,8,6,6,8,8,6,8,8,6,3,8,4,8,6,3,6,8,6,8,4,4,8,3,8,8,6,6,4,6,8,6,6,8,6,4,8,6,3,8,6,6,4,4,6,6,8,6,6,6,6,6,3,4,8,8,8,4,4,6,6,6,4,8,8,6,6,4,8,4,8,6,8,8,8,8,8,6,6,6,4,8,6,6,8 ...

# %%
pd.DataFrame(
    {"Sample": [sample_df["X"].mean(), sample_df["X"].var(), np.sqrt(sample_df["X"].var())],
     "Population": [sim_df["X(s)"].mean(), sim_df["X(s)"].var(), np.sqrt(sim_df["X(s)"].var())]}
)
# Out:
#      Sample  Population
# 0  5.990000    5.906900
# 1  2.979697    2.893019
# 2  1.726180    1.700888
